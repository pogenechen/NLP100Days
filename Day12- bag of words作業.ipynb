# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
nltk.word_tokenize(corpus[1])
# Out:
# ['Crust', 'is', 'not', 'good', '.']

# %% [markdown]
# ### 從文本中取出所有單字

# %%
#whole_word = []
#for sentence in corpus:
#    tokenized_sentence = nltk.word_tokenize(sentence)#'使用tokenize 技巧'
#    for word in tokenized_sentence:
#        whole_word.append(word)

whole_words = '|'.join(['|'.join(nltk.word_tokenize(i)) for i in corpus]).split('|')

# %% [markdown]
# ### 移除重複單字

# %%
whole_words_ = list(set(whole_words))
print('共有{}個單字'.format(len(whole_words_)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
#word_index = {}
#index_word = {}
#n = 0
#for word in whole_words:
#    """自行填入"""

word_index = {i:whole_words.index(i) for i in whole_words}
index_word = {whole_words.index(i):i for i in whole_words}

# %%
word_index
# Out:
# {'Wow': 0,
#  '...': 1,
#  'Loved': 2,
#  'this': 3,
#  'place': 4,
#  '.': 5,
#  'Crust': 6,
#  'is': 7,
#  'not': 8,
#  'good': 9,
#  'Not': 11,
#  'tasty': 12,
#  'and': 13,
#  'the': 14,
#  'texture': 15,
#  'was': 16,
#  'just': 17,
#  'nasty': 18,
#  'Stopped': 20,
#  'by': 21,
#  'during': 22,
#  'late': 24,
#  'May': 25,
#  'bank': 26,
#  'holiday': 27,
#  'off': 28,
#  'Rick': 29,
#  'Steve': 30,
#  'recommendation': 31,
#  'loved': 33,
#  'it': 34,
#  'The': 36,
#  'selection': 37,
#  'on': 38,
#  'menu': 40,
#  'great': 42,
#  'so': 44,
#  'were': 45,
#  'prices': 47,
#  'Now': 49,
#  'I': 50,
#  'am': 51,
#  'getting': 52,
#  'angry': 53,
#  'want': 56,
#  'my': 57,
#  'damn': 58,
#  'pho': 59,
#  'Honeslty': 61,
#  'did': 63,
#  "n't": 64,
#  'taste': 65,
#  'THAT': 66,
#  'fresh': 67,
#  ')': 69,
#  'potatoes': 71,
#  'like': 73,
#  'rubber': 74,
#  'you': 76,
#  'could': 77,
#  'tell': 78,
#  'they': 79,
#  'had': 80,
#  'been': 81,
#  'made': 82,
#  'up': 83,
# ...

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  11: 'Not',
#  12: 'tasty',
#  13: 'and',
#  14: 'the',
#  15: 'texture',
#  16: 'was',
#  17: 'just',
#  18: 'nasty',
#  20: 'Stopped',
#  21: 'by',
#  22: 'during',
#  24: 'late',
#  25: 'May',
#  26: 'bank',
#  27: 'holiday',
#  28: 'off',
#  29: 'Rick',
#  30: 'Steve',
#  31: 'recommendation',
#  33: 'loved',
#  34: 'it',
#  36: 'The',
#  37: 'selection',
#  38: 'on',
#  40: 'menu',
#  42: 'great',
#  44: 'so',
#  45: 'were',
#  47: 'prices',
#  49: 'Now',
#  50: 'I',
#  51: 'am',
#  52: 'getting',
#  53: 'angry',
#  56: 'want',
#  57: 'my',
#  58: 'damn',
#  59: 'pho',
#  61: 'Honeslty',
#  63: 'did',
#  64: "n't",
#  65: 'taste',
#  66: 'THAT',
#  67: 'fresh',
#  69: ')',
#  71: 'potatoes',
#  73: 'like',
#  74: 'rubber',
#  76: 'you',
#  77: 'could',
#  78: 'tell',
#  79: 'they',
#  80: 'had',
#  81: 'been',
#  82: 'made',
#  83: 'up',
# ...

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
            vector[word_index_dic[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])
